# %% [markdown]
# <h1 style = "color:#942222; text-align:center; font-weight: bold">Universidad Castro Carazo</h1>
# <h5 style = "color:#bd3737; text-align: center">Analisis de Datos</h5>
# <center><img src= "carro.png"></center>
# <br/>
# <p style = "text-align: justify; font-family: Tahoma">El análisis de datos es un proceso sistemático y metódico que implica la recopilación, organización, interpretación y visualización de conjuntos de datos con el objetivo de extraer información significativa y relevante. Este proceso utiliza herramientas, tecnologías y procesos para encontrar tendencias y resolver problemas mediante datos.
#  </p>

# %% [markdown]
# <table>
#   <tr>
#     <td> <img src = "info.png"></td>
#     <td>Repositorio UCI del set de datos</td>
#     <td><a href = "https://archive.ics.uci.edu/dataset/10/automobile">Enlace al sitio web </a></td>
#   </tr>
#   <tr>
#     <td> <img src = "paleta.png"></td>
#     <td>Paleta de colores</td>
#     <td><a href = "https://paletadecolores.com.mx/paleta/942222/bd3737/d4cdad/98c3a1/25857d/">Enlace al sitio web</a></td>
#   </tr>
# </table>

# %% [markdown]
# <h2 Style = "color: #25857d">1. Carga y estandarizacion de los set de datos</h2>
#
# <ul>
#     <li style="font-family: Tahoma">Instalar e importar las librerias necesarias para trabajar</li>
#     <li style="font-family: Tahoma">Importar los archivos csv (Set de Datos)</li>
#     <li style="font-family: Tahoma">Revison de los set de datos (encabezados)</li>
#     <li style="font-family: Tahoma">Generar un unico set de datos</li>
# </ul>
#
# <h4 style="color:#616382; font-family: Tahoma"> 1.1) Instalar e importar las librerias necesarias para trabajar </h4>

# %%
import numpy as np #Esta librería para trabajar estructuras de datos(listas, tuplas,diccionarios)
import pandas as pd #Librería utilizada para el manejo de datos(DataFrame)
import matplotlib as mpl #Librería para crear gráficos
import matplotlib.pyplot as plt #Librería de gráficos
import seaborn as sn #Librería de gráficos  

#La siguente linea de codigo es para quitar los warning que salen aveces en pantalla
import warnings 
warnings.filterwarnings("ignore")

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma"> 1.2) Importar Set de Datos</h4>

# %%
#Esta tupla es para definir los nombres de cada variable(columna)
cols = ["symboling", "Normalized", "make", "fuel", "aspiration", "doors", 
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylind3rs", "engine size", "system", "bor3", "stroke",
       "compression", "hOrsepower", "peak", "CITY", "Higway", "price"]

dfAutos1 = pd.read_csv("DataSet_Autos01(in).csv", names=cols) #names es asignarle los titulos a las columnas
dfAutos2 = pd.read_csv("DataSet_Autos02(in).csv", names=cols) #names es asignarle los titulos a las columnas
print("Se cargaron los datos a la memoria")
# Out:
# Se cargaron los datos a la memoria

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma"> 1.3) Revisar los Set de Datos</h4>

# %% [markdown]
# <table>
#   <tr>
#     <td> <img src = "info.png"></td>
#     <td>La primera columna de set de datos se tienen que revisar para poder determinar si esta correspónde a un indice o una variable, para eso se usan los MetaDatos</td>
#   </tr>

# %%
dfAutos1.head(5)
# Out:
#        symboling Normalized         make fuel aspiration doors        style  \
# NaN            3          ?  alfa-romero  gas        std   two  convertible
# 26.0           1        148        dodge  gas      turbo     ?        sedan
# 185.0          2         94   volkswagen  gas        std  four        sedan
# 112.0          0          ?       peugot  gas        std  four        wagon
# 78.0           1        161   mitsubishi  gas      turbo   two    hatchback
#
#       wheels engine   base  ...  engine size  system  bor3  stroke  \
# NaN      rwd  front   88.6  ...          130    mpfi  3.47    2.68
# 26.0     fwd  front   93.7  ...           98    mpfi  3.03    3.39
# 185.0    fwd  front   97.3  ...          109    mpfi  3.19    3.40
# 112.0    rwd  front  114.2  ...          120    mpfi  3.46    2.19
# 78.0     fwd  front   93.0  ...           98    spdi  3.03    3.39
#
#       compression hOrsepower  peak CITY Higway  price
# ...

# %%
dfAutos2.head(2)
# Out:
#      symboling Normalized         make fuel aspiration doors        style  \
# NaN          3          ?  alfa-romero  gas        std   two  convertible
# 4.0          2          ?         audi  gas        std   two        sedan
#
#     wheels engine  base  ...  engine size  system  bor3  stroke compression  \
# NaN    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 4.0    fwd  front  99.8  ...          136    mpfi  3.19    3.40         8.5
#
#     hOrsepower  peak CITY Higway  price
# NaN        111  5000   21     27  13495
# 4.0        110  5500   19     25  15250
#
# [2 rows x 26 columns]

# %%
dfAutos1.tail(5)
# Out:
#        symboling Normalized    make fuel aspiration doors      style wheels  \
# 161.0          0         91  toyota  gas        std  four      sedan    fwd
# 54.0           3        150   mazda  gas        std   two  hatchback    rwd
# 163.0          1        168  toyota  gas        std   two  hatchback    rwd
# 26.0           1        148   dodge  gas      turbo     ?      sedan    fwd
# 140.0          0        102  subaru  gas        std  four      sedan    fwd
#
#       engine  base  ...  engine size  system  bor3  stroke compression  \
# 161.0  front  95.7  ...           98    2bbl  3.19    3.03         9.0
# 54.0   front  95.3  ...           70    4bbl     ?       ?         9.4
# 163.0  front  94.5  ...           98    2bbl  3.19    3.03         9.0
# 26.0   front  93.7  ...           98    mpfi  3.03    3.39         7.6
# 140.0  front  97.2  ...          108    2bbl  3.62    2.64         9.5
#
#       hOrsepower  peak CITY Higway  price
# ...

# %%
dfAutos2.tail(5)
# Out:
#        symboling Normalized    make fuel aspiration doors      style wheels  \
# 36.0           0        106   honda  gas        std   two  hatchback    fwd
# 59.0           0        115   mazda  gas        std  four      sedan    fwd
# 164.0          1        168  toyota  gas        std   two      sedan    rwd
# 3.0            2        164    audi  gas        std  four      sedan    4wd
# 112.0          0          ?  peugot  gas        std  four      wagon    rwd
#
#       engine   base  ...  engine size  system  bor3  stroke compression  \
# 36.0   front   96.5  ...          110    1bbl  3.15    3.58         9.0
# 59.0   front   98.8  ...          122    2bbl  3.39    3.39         8.6
# 164.0  front   94.5  ...           98    mpfi  3.24    3.08         9.4
# 3.0    front   99.4  ...          136    mpfi  3.19    3.40         8.0
# 112.0  front  114.2  ...          120    mpfi  3.46    2.19         8.4
#
#       hOrsepower  peak CITY Higway  price
# ...

# %%
dfAutos1.shape
# Out:
# (201, 26)

# %%
#201 obervaciones y 26 columnas

# %%
dfAutos2.shape
# Out:
# (201, 26)

# %% [markdown]
# <ul>
#     <li style="font-family: Tahoma">Los nombres de variables no deben empezar con un número</li>
#     <li style="font-family: Tahoma">Los nombres no pueden ser iguales a una palabra reservada(for,if,print)</li>
#     <li style="font-family: Tahoma">Los nombres no deben contener espacios (engine size -> engineSize / engine-size)</li>
#     <li style="font-family: Tahoma">Los nombres de variables deben estar en el mismo idioma</li>
#     <li style="font-family: Tahoma">Los nombres de variables deben estar todos en minuscula o mayuscula</li>
# </ul>

# %%
dfAutos1.columns #esto es para revisar que todas las variables están exactamente igual a la hora de pegar dos archivos
# Out:
# Index(['symboling', 'Normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylind3rs', 'engine size', 'system', 'bor3',
#        'stroke', 'compression', 'hOrsepower', 'peak', 'CITY', 'Higway',
#        'price'],
#       dtype='object')

# %%
dfAutos2.columns
# Out:
# Index(['symboling', 'Normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylind3rs', 'engine size', 'system', 'bor3',
#        'stroke', 'compression', 'hOrsepower', 'peak', 'CITY', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma"> 1.4)Generar único Set de Datos</h4>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td><img src = "info.png"></td>
#         <td><p style="text-align: justify; font-family: Tahoma">Sanas prácticas para nombrar las variables:</p>
#             <ol>
#                 <li>Las variables deben llamarse igual</li>
#                 <li>Contener igual cantidad de valores, y estar en el mismo orden</li>
#          <o/>
#     </td>
# </tr>

# %%
unionArchivos = [dfAutos1, dfAutos2]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (402, 26)

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma"> 1.5) Solucionar los primeros errores identificados</h4>
# <table align="left">
#     <tr>
#         <td><img src = "info.png"></td>
#         <td><ol>
#                 <li>La columna 1 - un indice(Hay que eliminarla y generar un nuevo indice)</li>
#                 <li>Los errores de las variables (nombres)</li>
#          <o/>
#     </td>
# </tr>

# %%
dfAutos.head(5)
# Out:
#        symboling Normalized         make fuel aspiration doors        style  \
# NaN            3          ?  alfa-romero  gas        std   two  convertible
# 26.0           1        148        dodge  gas      turbo     ?        sedan
# 185.0          2         94   volkswagen  gas        std  four        sedan
# 112.0          0          ?       peugot  gas        std  four        wagon
# 78.0           1        161   mitsubishi  gas      turbo   two    hatchback
#
#       wheels engine   base  ...  engine size  system  bor3  stroke  \
# NaN      rwd  front   88.6  ...          130    mpfi  3.47    2.68
# 26.0     fwd  front   93.7  ...           98    mpfi  3.03    3.39
# 185.0    fwd  front   97.3  ...          109    mpfi  3.19    3.40
# 112.0    rwd  front  114.2  ...          120    mpfi  3.46    2.19
# 78.0     fwd  front   93.0  ...           98    spdi  3.03    3.39
#
#       compression hOrsepower  peak CITY Higway  price
# ...

# %%
dfAutos.reset_index(drop=True, inplace=True) #Esto es para resetear el indice(primeros numeros de los datos de la tabla) 
dfAutos
# Out:
#      symboling Normalized         make fuel aspiration doors        style  \
# 0            3          ?  alfa-romero  gas        std   two  convertible
# 1            1        148        dodge  gas      turbo     ?        sedan
# 2            2         94   volkswagen  gas        std  four        sedan
# 3            0          ?       peugot  gas        std  four        wagon
# 4            1        161   mitsubishi  gas      turbo   two    hatchback
# ..         ...        ...          ...  ...        ...   ...          ...
# 397          0        106        honda  gas        std   two    hatchback
# 398          0        115        mazda  gas        std  four        sedan
# 399          1        168       toyota  gas        std   two        sedan
# 400          2        164         audi  gas        std  four        sedan
# 401          0          ?       peugot  gas        std  four        wagon
#
#     wheels engine   base  ...  engine size  system  bor3  stroke compression  \
# ...

# %%
dfAutos.columns
# Out:
# Index(['symboling', 'Normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylind3rs', 'engine size', 'system', 'bor3',
#        'stroke', 'compression', 'hOrsepower', 'peak', 'CITY', 'Higway',
#        'price'],
#       dtype='object')

# %%
dfAutos.rename({'Normalized':'normalized', 'Cylind3rs':'cylinders', 'engine size':'engineSize',
                'bor3':'bore', 'hOrsepower':'horsepower', 'CITY':'city', 'Higway':'higway'},axis=1, inplace=True)
dfAutos.columns
#Axis = 1 es para que haga el cambio solo en las columnas y no en los datos de adentro
#inplace=True corra los cambios
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'city', 'higway',
#        'price'],
#       dtype='object')

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          1        148        dodge  gas      turbo     ?        sedan
# 2          2         94   volkswagen  gas        std  four        sedan
# 3          0          ?       peugot  gas        std  four        wagon
# 4          1        161   mitsubishi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    fwd  front   93.7  ...          98    mpfi  3.03    3.39         7.6
# 2    fwd  front   97.3  ...         109    mpfi  3.19    3.40         9.0
# 3    rwd  front  114.2  ...         120    mpfi  3.46    2.19         8.4
# 4    fwd  front   93.0  ...          98    spdi  3.03    3.39         7.6
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h2 Style = "color:  #25857d">2. Manejo de valores faltantes</h2>
#
# <ol>
# <li>Identificar como se muestran los valores faltantes (NaN, ?, null, EspacioEnBlanco)</li>
# <li>Contar la cantidad de valores faltantes en cada una de las caracteristicas</li>
# <li>Imputacion simple de valores numericos</li>
# <li>Imputacion simple de valores categoricos</li>
# <li>Eliminar observaciones o registros</li>
# </ol>
#
# <h4 style="color:#616382; font-family: Times New Roman">2.1 Identificar como se muestran los valores faltantes</h4>

# %%
dfAutos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          1        148        dodge  gas      turbo     ?        sedan
# 2          2         94   volkswagen  gas        std  four        sedan
# 3          0          ?       peugot  gas        std  four        wagon
# 4          1        161   mitsubishi  gas      turbo   two    hatchback
# 5          1        118        dodge  gas        std   two    hatchback
# 6          3          ?      porsche  gas        std   two      hardtop
# 7          1        168       toyota  gas        std   two        sedan
# 8          2        104         saab  gas        std  four        sedan
# 9          1        148        dodge  gas        std  four    hatchback
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...         130    mpfi  3.47    2.68        9.00
# ...

# %%
dfAutos["normalized"].unique() #Valores sin repetir(si hay tres: 110 entonces solo tira un 110) #es otra manera de identificar valores faltantes
# Out:
# array(['?', '148', '94', '161', '118', '168', '104', '74', '134', '164',
#        '90', '115', '158', '119', '85', '93', '150', '101', '231', '65',
#        '125', '128', '81', '197', '91', '129', '89', '256', '83', '103',
#        '188', '154', '110', '108', '87', '107', '137', '145', '153',
#        '102', '194', '122', '77', '106', '142', '113', '192', '121'],
#       dtype=object)

# %%
dfAutos["price"].unique()
# Out:
# array(['13495', '8558', '8495', '16695', '7689', '5572', '32528', '9298',
#        '12170', '6229', '13415', '11199', '17450', '8195', '16630',
#        '14489', '15690', '11900', '23875', '11245', '7957', '6669',
#        '8845', '15510', '28176', '15645', '7129', '18399', '10898',
#        '6989', '7995', '9279', '16500', '7799', '14869', '6575', '6785',
#        '18620', '9988', '9538', '31600', '11694', '12440', '5499',
#        '18150', '6095', '15998', '7738', '7463', '9980', '10595', '24565',
#        '7603', '11549', '12940', '?', '16558', '20970', '13950', '17075',
#        '25552', '36880', '6692', '9895', '8948', '8921', '13499', '13645',
#        '5348', '7053', '41315', '37028', '9258', '9989', '18920', '7609',
#        '17669', '6377', '10945', '10345', '15985', '35550', '15250',
#        '18280', '15040', '12945', '6855', '14399', '32250', '11248',
#        '9295', '9495', '8499', '7126', '18344', '9233', '6479', '7099',
# ...

# %% [markdown]
# <h4 style="color:#616382; font-family: Times New Roman">2.2 Contar valores faltantes</h4>

# %%
dfAutos.replace("?",np.nan,inplace=True)
dfAutos["normalized"].unique()
# Out:
# array([nan, '148', '94', '161', '118', '168', '104', '74', '134', '164',
#        '90', '115', '158', '119', '85', '93', '150', '101', '231', '65',
#        '125', '128', '81', '197', '91', '129', '89', '256', '83', '103',
#        '188', '154', '110', '108', '87', '107', '137', '145', '153',
#        '102', '194', '122', '77', '106', '142', '113', '192', '121'],
#       dtype=object)

# %%
dfTemp = dfAutos.isnull()
dfTemp.head(3)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False       False  False  False       False   True  False   False
# 2      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   city  higway  price
# 0       False  False  False   False  False
# 1       False  False  False   False  False
# 2       False  False  False   False  False
#
# [3 rows x 26 columns]

# %%
for columns in dfTemp.columns.values.tolist():
    print(dfTemp[columns].value_counts())
    print("")
# Out:
# symboling
# False    402
# Name: count, dtype: int64
#
# normalized
# False    318
# True      84
# Name: count, dtype: int64
#
# make
# False    402
# Name: count, dtype: int64
#
# fuel
# False    402
# Name: count, dtype: int64
#
# aspiration
# False    402
# Name: count, dtype: int64
#
# doors
# False    399
# True       3
# Name: count, dtype: int64
#
# style
# False    402
# Name: count, dtype: int64
#
# wheels
# False    402
# Name: count, dtype: int64
#
# engine
# False    402
# Name: count, dtype: int64
#
# base
# False    402
# Name: count, dtype: int64
#
# length
# False    402
# Name: count, dtype: int64
#
# width
# False    402
# Name: count, dtype: int64
#
# heingt
# False    402
# Name: count, dtype: int64
#
# curb
# False    402
# Name: count, dtype: int64
#
# engineType
# False    402
# Name: count, dtype: int64
#
# cylinders
# False    402
# Name: count, dtype: int64
#
# engineSize
# False    402
# Name: count, dtype: int64
#
# system
# False    402
# ...

# %% [markdown]
# <h4 style="color:#616382; font-family: Times New Roman">2.3 Imputar los valores numericos faltantes</h4>

# %%
dfTemp = dfAutos[dfAutos.peak.isnull()]
dfTemp.head(10)
# Out:
#      symboling normalized     make fuel aspiration doors      style wheels  \
# 83           2        NaN  renault  gas        std   two  hatchback    fwd
# 134          0        NaN  renault  gas        std  four      wagon    fwd
# 244          0        NaN  renault  gas        std  four      wagon    fwd
# 248          0        NaN  renault  gas        std  four      wagon    fwd
#
#     engine  base  ...  engineSize  system  bore  stroke compression  \
# 83   front  96.1  ...         132    mpfi  3.46    3.90         8.7
# 134  front  96.1  ...         132    mpfi  3.46    3.90         8.7
# 244  front  96.1  ...         132    mpfi  3.46    3.90         8.7
# 248  front  96.1  ...         132    mpfi  3.46    3.90         8.7
#
#     horsepower  peak city higway price
# 83         NaN   NaN   23     31  9895
# 134        NaN   NaN   23     31  9295
# 244        NaN   NaN   23     31  9295
# 248        NaN   NaN   23     31  9295
#
# [4 rows x 26 columns]

# %%
dfTemp = dfAutos[dfAutos["make"]=="renault"]
dfTemp.head(20)
# Out:
#      symboling normalized     make fuel aspiration doors      style wheels  \
# 83           2        NaN  renault  gas        std   two  hatchback    fwd
# 134          0        NaN  renault  gas        std  four      wagon    fwd
# 244          0        NaN  renault  gas        std  four      wagon    fwd
# 248          0        NaN  renault  gas        std  four      wagon    fwd
#
#     engine  base  ...  engineSize  system  bore  stroke compression  \
# 83   front  96.1  ...         132    mpfi  3.46    3.90         8.7
# 134  front  96.1  ...         132    mpfi  3.46    3.90         8.7
# 244  front  96.1  ...         132    mpfi  3.46    3.90         8.7
# 248  front  96.1  ...         132    mpfi  3.46    3.90         8.7
#
#     horsepower  peak city higway price
# 83         NaN   NaN   23     31  9895
# 134        NaN   NaN   23     31  9295
# 244        NaN   NaN   23     31  9295
# 248        NaN   NaN   23     31  9295
#
# [4 rows x 26 columns]

# %%
dfTemp = dfAutos[dfAutos.stroke.isnull()]
dfTemp.head(20)
# Out:
#      symboling normalized   make fuel aspiration doors      style wheels  \
# 26           3        150  mazda  gas        std   two  hatchback    rwd
# 92           3        150  mazda  gas        std   two  hatchback    rwd
# 113          3        150  mazda  gas        std   two  hatchback    rwd
# 183          3        150  mazda  gas        std   two  hatchback    rwd
# 197          3        150  mazda  gas        std   two  hatchback    rwd
# 378          3        150  mazda  gas        std   two  hatchback    rwd
#
#     engine  base  ...  engineSize  system  bore  stroke compression  \
# 26   front  95.3  ...          80    mpfi   NaN     NaN         9.4
# 92   front  95.3  ...          70    4bbl   NaN     NaN         9.4
# 113  front  95.3  ...          70    4bbl   NaN     NaN         9.4
# 183  front  95.3  ...          80    mpfi   NaN     NaN         9.4
# 197  front  95.3  ...          70    4bbl   NaN     NaN         9.4
# ...

# %%
dfTemp = dfAutos[dfAutos["make"]=="mazda"]
dfTemp.head(20)
# Out:
#      symboling normalized   make    fuel aspiration doors      style wheels  \
# 17           0        115  mazda     gas        std  four      sedan    fwd
# 20           0        115  mazda     gas        std  four  hatchback    fwd
# 26           3        150  mazda     gas        std   two  hatchback    rwd
# 51           1        104  mazda     gas        std   two  hatchback    fwd
# 56           1        129  mazda     gas        std   two  hatchback    fwd
# 61           1        129  mazda     gas        std   two  hatchback    fwd
# 92           3        150  mazda     gas        std   two  hatchback    rwd
# 113          3        150  mazda     gas        std   two  hatchback    rwd
# 121          0        118  mazda     gas        std  four      sedan    rwd
# 129          0        115  mazda     gas        std  four      sedan    fwd
# 130          1        129  mazda     gas        std   two  hatchback    fwd
# ...

# %%
dfTemp2 = dfTemp[dfTemp["style"]=="hatchback"]
dfTemp2.head(20)
# Out:
#      symboling normalized   make fuel aspiration doors      style wheels  \
# 20           0        115  mazda  gas        std  four  hatchback    fwd
# 26           3        150  mazda  gas        std   two  hatchback    rwd
# 51           1        104  mazda  gas        std   two  hatchback    fwd
# 56           1        129  mazda  gas        std   two  hatchback    fwd
# 61           1        129  mazda  gas        std   two  hatchback    fwd
# 92           3        150  mazda  gas        std   two  hatchback    rwd
# 113          3        150  mazda  gas        std   two  hatchback    rwd
# 130          1        129  mazda  gas        std   two  hatchback    fwd
# 150          0        115  mazda  gas        std  four  hatchback    fwd
# 183          3        150  mazda  gas        std   two  hatchback    rwd
# 197          3        150  mazda  gas        std   two  hatchback    rwd
# 214          1        129  mazda  gas        std   two  hatchback    fwd
# ...

# %%
dfTemp3 = dfTemp[dfTemp["horsepower"]=="101"]
dfTemp3.head(10)
# Out:
#      symboling normalized   make fuel aspiration doors      style wheels  \
# 92           3        150  mazda  gas        std   two  hatchback    rwd
# 113          3        150  mazda  gas        std   two  hatchback    rwd
# 197          3        150  mazda  gas        std   two  hatchback    rwd
# 378          3        150  mazda  gas        std   two  hatchback    rwd
#
#     engine  base  ...  engineSize  system  bore  stroke compression  \
# 92   front  95.3  ...          70    4bbl   NaN     NaN         9.4
# 113  front  95.3  ...          70    4bbl   NaN     NaN         9.4
# 197  front  95.3  ...          70    4bbl   NaN     NaN         9.4
# 378  front  95.3  ...          70    4bbl   NaN     NaN         9.4
#
#     horsepower  peak city higway  price
# 92         101  6000   17     23  13645
# 113        101  6000   17     23  10945
# 197        101  6000   17     23  10945
# 378        101  6000   17     23  13645
#
# [4 rows x 26 columns]

# %%
dfTemp3.loc[92,"stroke"]=3.39
dfTemp3.loc[113,"stroke"]=3.39
dfTemp3.loc[197,"stroke"]=3.39
dfTemp3.loc[378,"stroke"]=3.39
print("datos imputados")
# Out:
# datos imputados

# %%
dfAutos["stroke"].unique()
# Out:
# array(['2.68', '3.39', '3.40', '2.19', '3.23', '2.90', '3.08', '3.07',
#        '3.15', '3.50', '3.19', '3.86', '3.35', '3.58', '3.64', nan,
#        '3.41', '3.27', '3.54', '3.46', '3.29', '3.11', '2.64', '3.03',
#        '3.52', '3.90', '4.17', '3.16', '2.07', '3.47', '2.76', '3.12',
#        '3.10', '2.80'], dtype=object)

# %%
#Utilizar la variable: Normalized.
#Vamos a filtrar por la marca volkswagen
#Y las variables principales para encontrar patrones seran: make, fuel, aspiration, style, y horsepower

# %%
dfTemp = dfAutos[dfAutos.normalized.isnull()]
dfTemp.head(20)
# Out:
#      symboling normalized         make    fuel aspiration doors        style  \
# 0            3        NaN  alfa-romero     gas        std   two  convertible
# 3            0        NaN       peugot     gas        std  four        wagon
# 6            3        NaN      porsche     gas        std   two      hardtop
# 15           3        NaN   mitsubishi     gas      turbo   two    hatchback
# 34           3        NaN  alfa-romero     gas        std   two  convertible
# 37           3        NaN   mitsubishi     gas      turbo   two    hatchback
# 40           0        NaN        isuzu     gas        std  four        sedan
# 41           3        NaN   mitsubishi     gas      turbo   two    hatchback
# 48           0        NaN       peugot     gas        std  four        wagon
# 58           3        NaN   mitsubishi     gas      turbo   two    hatchback
# 62           1        NaN          bmw     gas        std  four        sedan
# ...

# %%
dfTemp1=dfAutos[dfAutos["make"]=="volkswagen"]
dfTemp1.head(20)
# Out:
#      symboling normalized        make    fuel aspiration doors      style  \
# 2            2         94  volkswagen     gas        std  four      sedan
# 13           2         94  volkswagen     gas        std  four      sedan
# 31           2         94  volkswagen  diesel        std  four      sedan
# 55           2         94  volkswagen     gas        std  four      sedan
# 59           2         94  volkswagen     gas        std  four      sedan
# 60           3        256  volkswagen     gas        std   two  hatchback
# 76           3        256  volkswagen     gas        std   two  hatchback
# 86           3        256  volkswagen     gas        std   two  hatchback
# 119          2         94  volkswagen     gas        std  four      sedan
# 136          2         94  volkswagen  diesel      turbo  four      sedan
# 143          2         94  volkswagen  diesel      turbo  four      sedan
# 153          2         94  volkswagen     gas        std  four      sedan
# ...

# %%
dfTemp2 = dfTemp1[dfTemp1["aspiration"]=="turbo"]
dfTemp2.head(20)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 136          2         94  volkswagen  diesel      turbo  four  sedan    fwd
# 143          2         94  volkswagen  diesel      turbo  four  sedan    fwd
# 172          0        NaN  volkswagen  diesel      turbo  four  sedan    fwd
# 276          2         94  volkswagen  diesel      turbo  four  sedan    fwd
# 312          2         94  volkswagen  diesel      turbo  four  sedan    fwd
# 347          0        NaN  volkswagen  diesel      turbo  four  sedan    fwd
#
#     engine   base  ...  engineSize  system  bore  stroke compression  \
# 136  front   97.3  ...          97     idi  3.01    3.40        23.0
# 143  front   97.3  ...          97     idi  3.01    3.40        23.0
# 172  front  100.4  ...          97     idi  3.01    3.40        23.0
# 276  front   97.3  ...          97     idi  3.01    3.40        23.0
# 312  front   97.3  ...          97     idi  3.01    3.40        23.0
# ...

# %%
dfTemp2.loc[172, "normalized"]=94
dfTemp2.loc[347, "normalized"]=94
print("datos imputados")
# Out:
# datos imputados

# %%
#dfTemp2 = dfTemp1[dfTemp1["fuel"]=="gas"]
#dfTemp2.head(20)

# %%
#dfTemp3 = dfTemp1[dfTemp1["horsepower"]=="110"]
#dfTemp3.head(20)

# %%
#dfTemp3 = dfTemp[dfTemp["aspiration"]=="std"]

# %%
#dfTemp4 = dfTemp[dfTemp["style"]=="sedan"]

# %%
#dfTemp5 = dfTemp[dfTemp["horsepower"]=="85"]

# %% [markdown]
# <h4 style="color:black; font-family: Tahoma"> Imputación de datos por el valor promedio</h4>

# %%
def calcPromedioInt (variable):
    average = int(dfAutos[variable].astype("float").mean(axis=0))
    return average

# %%
def calcPromedioFloat (variable):
    average = round(dfAutos[variable].astype("float").mean(axis=0),2)
    return average

# %%
def imputacionNumerica (variable,valor,dfAutos):
    if variable in dfAutos.columns:
        dfAutos[variable].replace(np.nan,valor,inplace=True)
        print("Imputacion correcta")
    else: 
        print(f"la columna {variable}no existe en el marco de datos")

# %%
#print(calcPromedio("normalized")) da 122.92138364779875

# %%
#ese 122 lo vamos a redondear, entonces sería 123

# %%
#round 0 lo que hace es que redondea automaticamente el numero, si le pongo 0, significa que quiero 0 decimales

# %%
imputacionNumerica("normalized",(calcPromedioInt("normalized")), dfAutos)
imputacionNumerica("peak",(calcPromedioInt("peak")), dfAutos)
imputacionNumerica("horsepower",(calcPromedioInt("horsepower")), dfAutos)
imputacionNumerica("stroke", (calcPromedioFloat("stroke")), dfAutos)
imputacionNumerica("bore", (calcPromedioFloat("bore")), dfAutos)
# Out:
# Imputacion correcta
# Imputacion correcta
# Imputacion correcta
# Imputacion correcta
# Imputacion correcta

# %%
dfAutos["normalized"].unique()
# Out:
# array([122, '148', '94', '161', '118', '168', '104', '74', '134', '164',
#        '90', '115', '158', '119', '85', '93', '150', '101', '231', '65',
#        '125', '128', '81', '197', '91', '129', '89', '256', '83', '103',
#        '188', '154', '110', '108', '87', '107', '137', '145', '153',
#        '102', '194', '122', '77', '106', '142', '113', '192', '121'],
#       dtype=object)

# %% [markdown]
# <h4 style="color:black; font-family: Tahoma"> Imputación de datos por el valor mas frecuente (categoricos)</h4>

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          1        148        dodge  gas      turbo   NaN        sedan
# 2          2         94   volkswagen  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    fwd  front  93.7  ...          98    mpfi  3.03    3.39         7.6
# 2    fwd  front  97.3  ...         109    mpfi  3.19    3.40         9.0
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# 1        102  5500   24     30   8558
# 2         85  5250   27     34   8495
#
# [3 rows x 26 columns]

# %%
dfAutos["doors"].value_counts().idxmax()
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace=True)
print("Imputacion categorica realizada")
# Out:
# Imputacion categorica realizada

# %%
dfAutos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          1        148        dodge  gas      turbo  four        sedan
# 2          2         94   volkswagen  gas        std  four        sedan
# 3          0        122       peugot  gas        std  four        wagon
# 4          1        161   mitsubishi  gas      turbo   two    hatchback
# 5          1        118        dodge  gas        std   two    hatchback
# 6          3        122      porsche  gas        std   two      hardtop
# 7          1        168       toyota  gas        std   two        sedan
# 8          2        104         saab  gas        std  four        sedan
# 9          1        148        dodge  gas        std  four    hatchback
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...         130    mpfi  3.47    2.68        9.00
# ...

# %% [markdown]
# <h4 style="color:black; font-family: Tahoma"> Eliminar observaciones</h4>

# %% [markdown]
# <h6 style="color:black; font-family: Tahoma"> si tengo una columna que tiene muchos muchos datos faltantes y no pertenece a ninguna pregunta de negocio, o si no es parte de las columnas que se deben considerar para realizar el analisis, la puedo eliminar
# IMPORTANTE: documentar siempre en el archivo la razon de porque se elimino la columna</h6>

# %%
dfAutos.dropna(subset=["price"], axis=0, inplace=True)
#Aqui como borré toda una fila, debo volver a resetear el indice 
dfAutos.reset_index(drop=True, inplace=True)

# %% [markdown]
# <h2 Style = "color: #25857d">3.Transformacion de datos</h2>
#
# <ol>
#     <li style="font-family: Tahoma">Formateo de Datos</li>
#     <li style="font-family: Tahoma">Tropicalizacion de Datos</li>
#     <li style="font-family: Tahoma">Agrupar Datos</li>
# </ol>
# <h4 style="color:#616382; font-family: Tahoma"> 3.1) Transformacion de Datos </h4>

# %%
#Toyota, toyota, Thoyota, oyota, TOYOTA necesito asegurarme que eso no esta pasando, que todas las filas de una columna dicen lo mismo y estan escritas igual
dfAutos["make"].unique()
# Out:
# array(['alfa-romero', 'dodge', 'volkswagen', 'peugot', 'mitsubishi',
#        'porsche', 'toyota', 'saab', 'volvo', 'audi', 'mazda', 'plymouth',
#        'honda', 'mercedes-benz', 'nissan', 'chevrolet', 'isuzu', 'subaru',
#        'bmw', 'renault', 'jaguar', 'mercury'], dtype=object)

# %%
#Si alguno de esos datos estuviera repetido pero escrito diferente cada uno o simplemente no esta escrito como quiero, entonces se transforma el dato
#forma 1
#dfAutos.replace("nissa", "dato que reemplazará", inplace=True)
#forma 2
dfAutos["make"]=dfAutos["make"].str.upper() ##lower()
dfAutos["fuel"]=dfAutos["fuel"].str.upper()
dfAutos["doors"]=dfAutos["doors"].str.upper()
dfAutos["style"]=dfAutos["style"].str.upper()
dfAutos["aspiration"]=dfAutos["aspiration"].str.upper()
dfAutos["wheels"]=dfAutos["wheels"].str.upper()
dfAutos["engine"]=dfAutos["engine"].str.upper()
dfAutos["system"]=dfAutos["system"].str.upper()

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  ALFA-ROMERO  GAS        STD   TWO  CONVERTIBLE
# 1          1        148        DODGE  GAS      TURBO  FOUR        SEDAN
# 2          2         94   VOLKSWAGEN  GAS        STD  FOUR        SEDAN
# 3          0        122       PEUGOT  GAS        STD  FOUR        WAGON
# 4          1        161   MITSUBISHI  GAS      TURBO   TWO    HATCHBACK
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    RWD  FRONT   88.6  ...         130    MPFI  3.47    2.68         9.0
# 1    FWD  FRONT   93.7  ...          98    MPFI  3.03    3.39         7.6
# 2    FWD  FRONT   97.3  ...         109    MPFI  3.19    3.40         9.0
# 3    RWD  FRONT  114.2  ...         120    MPFI  3.46    2.19         8.4
# 4    FWD  FRONT   93.0  ...          98    SPDI  3.03    3.39         7.6
#
#   horsepower  peak city higway  price
# 0        111  5000   21     27  13495
# ...

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma">Transformacion de Datos numericos, (dejar los datos solo con un decimal, primero hay que asegurarse que las columnas correspondientes son numericas correctamente y no str)</h4>

# %%
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    394 non-null    int64
#  1   normalized   394 non-null    object
#  2   make         394 non-null    object
#  3   fuel         394 non-null    object
#  4   aspiration   394 non-null    object
#  5   doors        394 non-null    object
#  6   style        394 non-null    object
#  7   wheels       394 non-null    object
#  8   engine       394 non-null    object
#  9   base         394 non-null    float64
#  10  length       394 non-null    float64
#  11  width        394 non-null    float64
#  12  heingt       394 non-null    float64
#  13  curb         394 non-null    int64
#  14  engineType   394 non-null    object
#  15  cylinders    394 non-null    object
#  16  engineSize   394 non-null    int64
#  17  system       394 non-null    object
# ...

# %%
dfAutos[["bore","stroke"]] = dfAutos[["bore","stroke"]].astype(float)
dfAutos[["price","horsepower","peak", "normalized"]] = dfAutos[["price","horsepower","peak", "normalized"]].astype(int)
dfAutos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 394 entries, 0 to 393
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    394 non-null    int64
#  1   normalized   394 non-null    int64
#  2   make         394 non-null    object
#  3   fuel         394 non-null    object
#  4   aspiration   394 non-null    object
#  5   doors        394 non-null    object
#  6   style        394 non-null    object
#  7   wheels       394 non-null    object
#  8   engine       394 non-null    object
#  9   base         394 non-null    float64
#  10  length       394 non-null    float64
#  11  width        394 non-null    float64
#  12  heingt       394 non-null    float64
#  13  curb         394 non-null    int64
#  14  engineType   394 non-null    object
#  15  cylinders    394 non-null    object
#  16  engineSize   394 non-null    int64
#  17  system       394 non-null    object
# ...

# %%
dfAutos["stroke"]=dfAutos["stroke"].round(1)
dfAutos["base"]=dfAutos["base"].round(1)
dfAutos["bore"]=dfAutos["bore"].round(1)
dfAutos["length"]=dfAutos["length"].round(1)
dfAutos["width"]=dfAutos["width"].round(1)
dfAutos["heingt"]=dfAutos["heingt"].round(1)
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  ALFA-ROMERO  GAS        STD   TWO  CONVERTIBLE
# 1          1         148        DODGE  GAS      TURBO  FOUR        SEDAN
# 2          2          94   VOLKSWAGEN  GAS        STD  FOUR        SEDAN
# 3          0         122       PEUGOT  GAS        STD  FOUR        WAGON
# 4          1         161   MITSUBISHI  GAS      TURBO   TWO    HATCHBACK
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    RWD  FRONT   88.6  ...         130    MPFI   3.5     2.7         9.0
# 1    FWD  FRONT   93.7  ...          98    MPFI   3.0     3.4         7.6
# 2    FWD  FRONT   97.3  ...         109    MPFI   3.2     3.4         9.0
# 3    RWD  FRONT  114.2  ...         120    MPFI   3.5     2.2         8.4
# 4    FWD  FRONT   93.0  ...          98    SPDI   3.0     3.4         7.6
#
#   horsepower  peak city  higway  price
# 0        111  5000   21      27  13495
# ...

# %%
dfAutos["compression"].unique()
# Out:
# array([ 9.  ,  7.6 ,  8.4 ,  9.41,  9.5 ,  9.4 ,  9.3 ,  8.  ,  7.  ,
#         9.2 ,  8.6 ,  8.3 , 21.5 ,  8.7 ,  8.5 , 23.  ,  7.5 ,  9.6 ,
#         7.7 , 10.  , 21.  ,  9.1 ,  8.1 , 22.  , 21.9 , 11.5 ,  7.8 ,
#        10.1 , 22.5 ,  9.31,  8.8 ])

# %%
dfAutos[["compression"]] = dfAutos[["compression"]].astype(int)
dfAutos["compression"].unique()
# Out:
# array([ 9,  7,  8, 21, 23, 10, 22, 11])

# %%
#Siempre hay que revisar despues de hacer todos estos cambios al set de datos, siempre hay que revisar una por una todas las columnas para ver que estn bien 
#aunque sean muchas

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma">3.2 Tropicalización de datos</h4>

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  ALFA-ROMERO  GAS        STD   TWO  CONVERTIBLE
# 1          1         148        DODGE  GAS      TURBO  FOUR        SEDAN
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    RWD  FRONT  88.6  ...         130    MPFI   3.5     2.7           9
# 1    FWD  FRONT  93.7  ...          98    MPFI   3.0     3.4           7
#
#   horsepower  peak city  higway  price
# 0        111  5000   21      27  13495
# 1        102  5500   24      30   8558
#
# [2 rows x 26 columns]

# %%
dfAutos["consumoCiudad(calc)"]=235.21/dfAutos["city"]
dfAutos["consumoCiudad(calc)"]=dfAutos["consumoCiudad(calc)"].round(1)

dfAutos["consumoPista(calc)"]=235.21/dfAutos["city"]
dfAutos["consumoPista(calc)"]=dfAutos["consumoPista(calc)"].round(1)

dfAutos.head(4)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  ALFA-ROMERO  GAS        STD   TWO  CONVERTIBLE
# 1          1         148        DODGE  GAS      TURBO  FOUR        SEDAN
# 2          2          94   VOLKSWAGEN  GAS        STD  FOUR        SEDAN
# 3          0         122       PEUGOT  GAS        STD  FOUR        WAGON
#
#   wheels engine   base  ...  bore  stroke  compression  horsepower  peak city  \
# 0    RWD  FRONT   88.6  ...   3.5     2.7            9         111  5000   21
# 1    FWD  FRONT   93.7  ...   3.0     3.4            7         102  5500   24
# 2    FWD  FRONT   97.3  ...   3.2     3.4            9          85  5250   27
# 3    RWD  FRONT  114.2  ...   3.5     2.2            8          95  5000   19
#
#    higway  price  consumoCiudad(calc)  consumoPista(calc)
# 0      27  13495                 11.2                11.2
# 1      30   8558                  9.8                 9.8
# ...

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma">3.3 Agrupaciones de datos</h4>

# %%
#Funciona solo con datos numericos
#Basicamente es agrupar los datos para que sea mas facil graficarlos

# %%
bins = np.linspace(min(dfAutos["horsepower"]),max(dfAutos["horsepower"]),4) #valor minimo, valor maximo, y en cuantos pedazos quiero que lo parta, 5 cortes son 4 rangos por ejemplo entre uno y otro
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
grupo = ["HPbajo","HPmedio","HPalto"]
dfAutos["gruposHP"] = pd.cut(dfAutos["horsepower"], bins, labels=grupo, include_lowest=True)#Include lowest es para que incluya el numero mas bajo tambien
dfAutos.head(4)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  ALFA-ROMERO  GAS        STD   TWO  CONVERTIBLE
# 1          1         148        DODGE  GAS      TURBO  FOUR        SEDAN
# 2          2          94   VOLKSWAGEN  GAS        STD  FOUR        SEDAN
# 3          0         122       PEUGOT  GAS        STD  FOUR        WAGON
#
#   wheels engine   base  ...  stroke  compression  horsepower  peak city  \
# 0    RWD  FRONT   88.6  ...     2.7            9         111  5000   21
# 1    FWD  FRONT   93.7  ...     3.4            7         102  5500   24
# 2    FWD  FRONT   97.3  ...     3.4            9          85  5250   27
# 3    RWD  FRONT  114.2  ...     2.2            8          95  5000   19
#
#   higway  price consumoCiudad(calc)  consumoPista(calc)  gruposHP
# 0     27  13495                11.2                11.2    HPbajo
# 1     30   8558                 9.8                 9.8    HPbajo
# ...

# %% [markdown]
# <h4 style="color:#616382; font-family: Tahoma">4 Visualizacion de datos</h4>
#  <ol>
#     <li>Gráfica de barras</li>
#     <li>Gráficas circulares</li>
#     <li>Gráficas de dispercion</li>
# <o/>
# <h4 style="color:#616382; font-family: Tahoma">4.1 grafico de barras</h4>

# %%
mpl.rcParams["axes.spines.bottom"]=True
mpl.rcParams["axes.spines.top"]=False
mpl.rcParams["axes.spines.left"]=True
mpl.rcParams["axes.spines.right"]=False

# %%
#-------------------------------------------------------------------------------------------------#
#Parametros: dfParam -> Es el set de datos completo,
#            nomColumna -> El nombre de la variable por la cual voy a agrupar los datos.
#            orden -> True para que ordenado de menor a mayor, False para se ordene de mayor a menor
#-------------------------------------------------------------------------------------------------#
def agrupaYcuenta (dfParam,nomColumna, orden):
    gf = dfParam.groupby([nomColumna]).count()
    gf = gf.iloc[:,:1]#iloc es para filtrar, seleccionar columnas
    gf.rename({"symboling":"cantidad"}, axis=1, inplace=True)
    gf = gf.sort_values("cantidad", ascending=orden)
    return gf

# %% [markdown]
# Pregunta de negocio: cuantos autos hay segun el tipo de combustible

# %%
dfAgrupado = agrupaYcuenta(dfAutos, "fuel", False)
#----------------------------------------GRAFIICO DE BARRAS--------------------------------------------------#
fig, ax = plt.subplots(1,1, figsize = (15, 6.9), dpi=100)

etiquetaBarras= dfAgrupado.index.tolist()
alturaBarras = dfAgrupado["cantidad"].tolist()
coloresBarras = ["#d4cdad","#942222"]

gBarra = ax.bar(etiquetaBarras, alturaBarras, color=coloresBarras)

#-----------------------------------------CONFIG. DEL GRAFICO-----------------------------------------------------------------------#
titulo = "Grafico 1: Lote de autos para inventario PK2"
plt.suptitle(titulo,
            horizontalalignment = 'left',
            x = 0.001,
            y = 0.87,
            transform = fig.transFigure,
            fontsize = 20,
            fontweight = 'bold',
            fontfamily = 'serif')

subtitulo = "Cantidad de vehiculos agrupados segun el tipo de combustible, periodo 2001"
ax.set_title(subtitulo,
            ha = 'left',
            x = 0.001,
            y = 0.80,
            transform = fig.transFigure,
            fontsize = 12,
            fontweight = 'regular',
            fontfamily = 'serif')

etiquetax = "Tipo de Combustible"
ax.set_xlabel(etiquetax,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')

etiquetay = "Cantidad de autos"
ax.set_ylabel(etiquetay,
             ha = 'left',
             fontsize = 10,
             fontweight = 'regular',
             fontfamily = 'serif')

ax.xaxis.set_label_coords(x=0, y = - 0.07, transform = ax.transAxes)
ax.yaxis.set_label_coords(x=-0.05, y = 0.68, transform = ax.transAxes)

#---------------------------------------------------------------------------------------------#
#-------------------------------Crear etiqueta para cada barra--------------------------------#
#---------------------------------------------------------------------------------------------#
for barra in gBarra:
    altura = barra.get_height()
    ax.text(barra.get_x() + barra.get_width() / 2, altura, str(altura), ha='center', va='bottom', fontsize=10, color='black')
#---------------------------------------------------------------------------------------------#


plt.subplots_adjust(top= 0.75)
plt.show()

# %% [markdown]
# Pregunta de negocio: cuantos autos hay segun el tipo de combustible
